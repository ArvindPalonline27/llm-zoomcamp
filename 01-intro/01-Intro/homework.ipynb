# %%
import openai

# %%
from openai import OpenAI

# %%
client = OpenAI()

# %%
import os

# %%
responses = client.chat.completions.create(
    model='gpt-5.4',
    messages=[{"role": "user", "content": "is it too late to join the course?"}]
)

# %%
responses.choices[0].message.content
# Out:
# 'I can help with that, but I need a bit more context.\n\nPlease tell me:\n- **Which course** you mean\n- **What institution/platform** it’s through\n- Whether you mean **joining after the start date**, **registering after the deadline**, or **catching up on missed work**\n\nIf you want, I can also help you draft a quick message to the instructor or admin asking if late enrollment is still possible.'
